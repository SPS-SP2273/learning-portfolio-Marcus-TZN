# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1 (Fill in the blanks)

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr= x_err, yerr=y_err,
             color='red', linestyle='dashed',
             marker='o', markerfacecolor='y',
             ecolor='black',capsize=5,
             label="Y Value with Errors")
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 2 (A simple mathematical plot)

# %%
import numpy as np

x = np.linspace(0,50,10000)
e = np.exp(-(x/10))
s = np.sin(x)
y = e*s

from matplotlib import pyplot as plt

plt.plot(x,y,color='blue')
plt.xlabel('x',color='darkorange',fontsize='15')
plt.ylabel('y',color='darkorange',fontsize='15',rotation=0)
plt.ylim([-1,1])
plt.grid(alpha=.25)

Title = r' $y = e^{-\frac{x}{10}}\sin(x)$'           # Sorry I prefer the fraction to be more elegant so no -x/10 from me
plt.title(Title,fontsize=20)
# Out:
# Text(0.5, 1.0, ' $y = e^{-\\frac{x}{10}}\\sin(x)$')
