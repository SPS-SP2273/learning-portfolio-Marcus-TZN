# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises (Completed)</span></div>

# %% [markdown]
# # **Exercise 1 (Learning to interrupt)**

# %%
while True:
    print('*', end='')

# I aint gna run cell, this is gna generate an infintie amount of asterisk and idw to crash my notebook
# Anyways I can interrupt the kernel by pressing the black stop square, or esc I I, or just restart the kernel

# %% [markdown]
# This is a snippet of the output
#
# \*******************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
#
# And still counting

# %% [markdown]
# # **Exercise 2 (Resetting & Restarting the Kernal)**

# %%
print = "Print"

# %%
print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("Hello World")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Yesh I messed up the print function by running the two codes in order above.
# Restart the kernel by esc-0-0
#
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("Hello World")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Footnotes
