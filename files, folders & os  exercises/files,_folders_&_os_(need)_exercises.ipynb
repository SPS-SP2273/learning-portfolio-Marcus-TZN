# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1 (Tidying a collaboration)

# %%
import os
import glob
import shutil

# %% [markdown]
# ## Task 1

# %%
split1 = 'oct-08_singapore.txt'.split('.')
split2 = split1[0].split('-')
extracted_month, date_and_location = split2

month_dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

mm = month_dictionary[extracted_month]

new_name = f'{mm}-{date_and_location}.txt'

new_name
# Out:
# '10-08_singapore.txt'

# %% [markdown]
# ## Task 2

# %%
month_dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }

def rename_my_file(old_file_name):                        # Define this function
    split1 = old_file_name.split('.')
    split2 = split1[0].split('-')
    extracted_month, date_and_location = split2

    mm = month_dictionary[extracted_month]
    new_name = f'{mm}-{date_and_location}.txt'

    return (f'{old_file_name} is renamed to {new_name} successfully!')

# %% [markdown]
# ## Task 3

# %%
# Practise by renaming files without modifying the folder first

Files = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
         'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
         'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
         'jan-01_tokyo.txt']

month_dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }


for file in Files:
    rename_my_file(file)

# %% [markdown]
# ## Task 4

# %%
# Now lets get to renaming the txt files in the folder
#Adjust the function abit

month_dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }


def rename_my_file(old_file_name):                        # Define this function again
    
    try:
        oldpath = os.path.join('.','os-collaboration-exercise-data',old_file_name)

        split1 = old_file_name.split('.')
        split2 = split1[0].split('-')

        extracted_month, date_and_location = split2

        mm = month_dictionary[extracted_month]
        new_name = f'{mm}-{date_and_location}.txt'

        oldpath = os.path.join('.','os-collaboration-exercise-data',old_file_name)
        newpath = os.path.join('.','os-collaboration-exercise-data',new_name)

        os.rename(oldpath, newpath)
        print(f'{old_file_name} is renamed to {new_name} successfully!')
        
    except:
        print(f'Unable to rename {old_file_name}! Check the file name if it has been renamed yet!')


Files = glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True)
for File in Files:
    Filename = os.path.split(File)[1]
    rename_my_file(Filename)
# Out:
# Unable to rename 01-02_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-03_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-04_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-05_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-07_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-08_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-09_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-11_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-12_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-13_cairo.txt! Check the file name if it has been renamed yet!
# Unable to rename 01-15_cairo.txt! Check the file name if it has been renamed yet!
# ...

# %% [markdown]
# ## Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
        'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

path = os.path.join('.','os-collaboration-exercise-data')

for city in cities:
    try:
        folder_path = os.path.join(path, city)
        os.mkdir(folder_path)
        print(f'Creating folder for {city}... Completed!')
    except:
        print(f'{folder_path} already exists...skipping file creation.')
# Out:
# .\os-collaboration-exercise-data\Cairo already exists...skipping file creation.
# .\os-collaboration-exercise-data\Dhaka already exists...skipping file creation.
# .\os-collaboration-exercise-data\Jakarta already exists...skipping file creation.
# .\os-collaboration-exercise-data\Karachi already exists...skipping file creation.
# .\os-collaboration-exercise-data\Manila already exists...skipping file creation.
# .\os-collaboration-exercise-data\Melbourne already exists...skipping file creation.
# .\os-collaboration-exercise-data\Osaka already exists...skipping file creation.
# .\os-collaboration-exercise-data\Shanghai already exists...skipping file creation.
# .\os-collaboration-exercise-data\Singapore already exists...skipping file creation.
# .\os-collaboration-exercise-data\Tokyo already exists...skipping file creation.

# %% [markdown]
# ## Task 6

# %%
Cairo_Files = glob.glob('os-collaboration-exercise-data/**/*cairo.*', recursive = True)  # Move all Cairo Files

for files in Cairo_Files:
    path_to_destination = os.path.join('os-collaboration-exercise-data','Cairo')
    shutil.copy(files, path_to_destination)
    print(f'Copied {file} to {path_to_destination}!')
# Out:
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# Copied os-collaboration-exercise-data\Cairo\01-02_cairo.txt to os-collaboration-exercise-data\Cairo!
# ...

# %% [markdown]
# ## Task 7

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
        'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
    files = glob.glob(f'os-collaboration-exercise-data/**/*{city}.*', recursive = True)

    for file in files:
        path_to_destination = os.path.join('os-collaboration-exercise-data',city)
        shutil.copy(file, path_to_destination)
        os.remove(file)
    
    print(f'Successfully move files from {city} into its folder!')
# Out:
# Successfully move files from Cairo into its folder!
# Successfully move files from Dhaka into its folder!
# Successfully move files from Jakarta into its folder!
# Successfully move files from Karachi into its folder!
# Successfully move files from Manila into its folder!
# Successfully move files from Melbourne into its folder!
# Successfully move files from Osaka into its folder!
# Successfully move files from Shanghai into its folder!
# Successfully move files from Singapore into its folder!
# Successfully move files from Tokyo into its folder!
